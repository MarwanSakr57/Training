# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
df = pd.read_csv('Weather Dataset.csv')
df.drop_duplicates(inplace=True)
df.dropna(how='all')
# Out:
#                      Formatted Date        Summary Precip Type  \
# 0     2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1     2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2     2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3     2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4     2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                             ...            ...         ...
# 2516  2006-02-20 20:00:00.000 +0100  Mostly Cloudy        rain
# 2517  2006-02-20 21:00:00.000 +0100  Mostly Cloudy        rain
# 2518  2006-02-20 22:00:00.000 +0100  Mostly Cloudy        rain
# 2519  2006-02-20 23:00:00.000 +0100  Mostly Cloudy        rain
# 3247  2006-08-23 18:00:00.000 +0200  Partly Cloudy        rain
#
#       Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0            9.472222                  7.388889      0.89            14.1197
# ...

# %%
df=df.sort_values(by ='Formatted Date',ascending =True)
df = df.dropna()
columns= [ "Humidity", "Wind Speed (km/h)", "Wind Bearing (degrees)", "Visibility (km)", "Pressure (millibars)"]
for column in columns:
    df = df[df[column] >= 0]
df=df[df['Temperature (C)']>-50]
df=df[df['Apparent Temperature (C)']>-50]
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      2518.000000               2518.000000  2518.000000
# mean         10.139782                  9.068233     0.807963
# std           8.811666                  9.924846     0.161970
# min          -8.594444                -11.911111     0.320000
# 25%           2.156944                 -0.293056     0.710000
# 50%          10.577778                 10.577778     0.860000
# 75%          17.148611                 17.148611     0.930000
# max          32.638889                 35.494444     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count        2518.000000             2518.000000      2518.000000
# mean           10.006745              201.581811         8.827704
# std             5.956688               91.248996         4.544770
# min             0.000000                0.000000         0.000000
# 25%             5.313000              146.000000         5.546450
# ...

# %%
x = df['Formatted Date']
y = df ['Apparent Temperature (C)']
plt.figure(figsize=(10, 5))
plt.plot(x,y)
plt.title('Temperature (C)')
plt.xlabel('Time')
plt.ylabel('Temperature (C)')
plt.show()

# %%
plt.hist(df['Apparent Temperature (C)'],bins =10,color='Purple',edgecolor='Black')
plt.title('Distribution of Temperature ')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['Humidity'],df['Apparent Temperature (C)'])
plt.title("Temperature Vs Humidity")
plt.ylabel('Temperature')
plt.xlabel('Humidity')
# Out:
# Text(0.5, 0, 'Humidity')

# %%
col= [ "Temperature (C)","Apparent Temperature (C)","Humidity", "Wind Speed (km/h)", "Wind Bearing (degrees)", "Visibility (km)", "Pressure (millibars)"]
data = df[col]

# %%
plt.figure(figsize=(10, 8))
sn.heatmap(data.corr(),annot=True ,cmap ='hot')
plt.title('Heatmap of Weather Dataset')
plt.show()

# %%
print(df.describe())
# Out:
#        Temperature (C)  Apparent Temperature (C)     Humidity  \
# count      2518.000000               2518.000000  2518.000000
# mean         10.139782                  9.068233     0.807963
# std           8.811666                  9.924846     0.161970
# min          -8.594444                -11.911111     0.320000
# 25%           2.156944                 -0.293056     0.710000
# 50%          10.577778                 10.577778     0.860000
# 75%          17.148611                 17.148611     0.930000
# max          32.638889                 35.494444     1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count        2518.000000             2518.000000      2518.000000
# mean           10.006745              201.581811         8.827704
# std             5.956688               91.248996         4.544770
# min             0.000000                0.000000         0.000000
# 25%             5.313000              146.000000         5.546450
# ...
